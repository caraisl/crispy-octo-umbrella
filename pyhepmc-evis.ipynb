# %% [markdown]
# # pyhepmc
#
# https://scikit-hep.org/pyhepmc/reference.html

# %%
# %pip install pyhepmc
# !conda info
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#
#      active environment : base
#     active env location : /home/ppd/cara.lewis/miniconda3
#             shell level : 1
#        user config file : /home/ppd/cara.lewis/.condarc
#  populated config files : /home/ppd/cara.lewis/miniconda3/.condarc
#                           /home/ppd/cara.lewis/miniconda3/condarc.d/anaconda-auth.yml
#           conda version : 26.3.2
#     conda-build version : not installed
#          python version : 3.13.13.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=skylake
#                           __conda=26.3.2=0
#                           __glibc=2.34=0
#                           __linux=5.14.0=0
#                           __unix=0=0
#        base environment : /home/ppd/cara.lewis/miniconda3  (writable)
# ...

# %%
# !pip freeze
# Out:
# anaconda-anon-usage @ file:///home/task_177490767889375/croot/anaconda-anon-usage_1774907925443/work
# anaconda-auth @ file:///home/task_177681132732760/croot/anaconda-cloud-auth-split_1776812130933/work
# anaconda-cli-base @ file:///home/task_177546922169020/croot/anaconda-cli-base_1775469250358/work
# annotated-types @ file:///home/task_176174487847081/conda-bld/annotated-types_1761744928471/work
# anyio @ file:///home/task_177313440431767/croot/anyio_1773134428538/work
# archspec @ file:///home/task_175812491784513/conda-bld/archspec_1758124989039/work
# backports.zstd==1.7.0
# boltons @ file:///croot/boltons_1751383775419/work
# brotlicffi @ file:///home/task_176496126124857/conda-bld/brotlicffi_1764961326114/work
# certifi @ file:///home/task_177697098542695/croot/certifi_1776971111806/work/certifi
# cffi @ file:///croot/cffi_1736182485317/work
# charset-normalizer @ file:///home/task_176174481524083/conda-bld/charset-normalizer_1761744828711/work
# ...

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# 4c842c94c09923bae9e4__mypyc base64              jsonpointer         rfc3987_syntax
# 81d243bd2c585b0f4821__mypyc bdb                 jsonschema          rlcompleter
# IPython             binascii            jsonschema_specifications rpds
# PIL                 binhex              jupyter             rpm
# __future__          bisect              jupyter_client      runpy
# _abc                bleach              jupyter_core        sched
# _aix_support        bs4                 jupyter_events      scipy
# _argon2_cffi_bindings builtins            jupyter_lsp         secrets
# _ast                bz2                 jupyter_server      select
# _asyncio            cProfile            jupyter_server_terminals selectors
# _audit              calendar            jupyterlab          selinux
# _bisect             certifi             jupyterlab_pygments semanage
# ...

# %%
import pyhepmc
with pyhepmc.open("neut.EDRMF.DCC5D.MicroBooNE.250000Ev.hepmc3.gz") as f:
    event = f.read()
event
# Out:
# <GenEvent momentum_unit=0, length_unit=0, event_number=0, particles=8, vertices=3, run_info=GenRunInfo(tools=[ToolInfo(name='NEUT', version='6.2.0', description='https://doi.org/10.1140/epjs/s11734-021-00287-7')], weight_names=['CV'], attributes={NuHepMC.Beam.EnergyUnit: GEV, NuHepMC.Beam.RateUnit: #frac{Number of #nu_{#mu}}{1.592 #upoint 10^{20} POT cm^{2} 0.05 GeV}, NuHepMC.Beam.Type: Histogram, NuHepMC.Beam[14].Histogram.BinContent: 24627200.000000 94533000.000000 122210496.000000 145618000.000000 180872496.000000 199318496.000000 213119008.000000 223194496.000000 236011488.000000 246111008.000000 251703504.000000 252103984.000000 248851504.000000 246293504.000000 243755008.000000 238064512.000000 229157984.000000 219608496.000000 210062496.000000 198866000.000000 188562000.000000 176640496.000000 164375504.000000 152730000.000000 141608496.000000 128901504.000000 117326000.000000 105118000.000000 92988000.000000 81045496.000000 70605496.000000 60962504.000000 51810000.000000 4367
# ...
